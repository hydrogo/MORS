# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
sys.path.append('../models/')
import hbv_s

# %%
swe_riv = pd.read_csv('../data/hbv_s_data.csv', index_col=0)

# %%
Qobs = swe_riv.Qobs
Qsim = hbv_s.simulation(swe_riv)

# %%
pd.DataFrame({'obs':Qobs, 'sim':Qsim}, index=swe_riv.index).plot()
